# %%
# Convert categorical to numeric
import pandas as pd


df = pd.read_csv('../data/WA_Fn-UseC_-Telco-Customer-Churn.csv')  # Adjust path if data file location differs
df = pd.get_dummies(df, drop_first=True)

# Target variable
y = df['Churn_Yes']
X = df.drop('Churn_Yes', axis=1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 5
#       1 # Convert categorical to numeric
#       2 import pandas as pd
# ----> 5 df = pd.get_dummies(df, drop_first=True)
#       7 # Target variable
#       8 y = df['Churn_Yes']
#
# NameError: name 'df' is not defined
