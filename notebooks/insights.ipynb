# %%
from pyexpat import model
from re import X

import pandas as pd

coefficients = pd.DataFrame({
    "Feature": model.feature_names_in_,
    "Impact": model.coef_[0]
}).sort_values(by="Impact", ascending=False)

print(coefficients.head(10))
print(coefficients.head(10))

print(coefficients.head(10))

print(coefficients.head(10))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[2], line 7
#       2 from re import X
#       4 import pandas as pd
#       6 coefficients = pd.DataFrame({
# ----> 7     "Feature": model.feature_names_in_,
#       8     "Impact": model.coef_[0]
#       9 }).sort_values(by="Impact", ascending=False)
#      11 print(coefficients.head(10))
#      12 print(coefficients.head(10))
#
# AttributeError: module 'pyexpat.model' has no attribute 'feature_names_in_'
